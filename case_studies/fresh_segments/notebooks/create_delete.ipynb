# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

import os
import sys

sys.path.append("../../../")
from src.athena import Athena
from src.utils import create_session

# %% [markdown]
# ## Global

# %%
boto3_session = create_session(
    profile_name="dev",
    role_arn="arn:aws:iam::722696965592:role/athena-full-access-role",
)

wait = True
ctas_approach = False

database = "fresh_segments"
tables = ["interest_map", "interest_metrics"]
sql_path = "../sql/"

athena = Athena(boto3_session=boto3_session, s3_output=os.getenv("ATHENA_S3_OUTPUT"))
athena
# Out:
# Athena(boto3_session=Session(region_name='us-east-1'), s3_output=s3://sql-case-studies/query_results)

# %% [markdown]
# ## Create Database & Table

# %%
response = athena.create_database(database=database, wait=wait)

response
# Out:
# Query executed successfully

# %%
ddls = {}
for table in tables:
    with open(os.path.join(sql_path, f"{table}_ddl.sql"), "r") as f:
        ddls[table] = f.read()

    print(ddls[table])
    print("-" * 50)
    print("\n")
# Out:
# CREATE EXTERNAL TABLE IF NOT EXISTS fresh_segments.interest_map (
#   id INT COMMENT 'Unique identifier for the interest',
#   interest_name VARCHAR(100) COMMENT 'Name of the interest',
#   interest_summary VARCHAR(500) COMMENT 'Brief summary or description of the interest',
#   created_at TIMESTAMP COMMENT 'Timestamp when the record was created',
#   last_modified TIMESTAMP COMMENT 'Timestamp when the record was last modified'
# )
# COMMENT 'The interest map table links the interest IDs with the relevant interest names and summaries'
# STORED AS PARQUET
# LOCATION 's3://sql-case-studies/fresh_segments/interest_map/'
# TBLPROPERTIES ('classification'='parquet', 'parquet.compress'='SNAPPY');
#
# --------------------------------------------------
#
#
# CREATE EXTERNAL TABLE IF NOT EXISTS fresh_segments.interest_metrics (
#   record_month INT COMMENT 'Represents the month of the record',
#   record_year INT COMMENT 'Represents the year of the record',
#   month_year VARCHAR(7) COMMENT 'Month and year concatenated as a string in the format MM-YYYY',
#   interest_id INT COMMENT 'Unique identifier for the interest',
#   composition DOUBLE COMMENT 'Represents the composition percentage of the interest (e.g., 11.89% of the client’s customer list interacted with the interest)',
#   index_value DOUBLE COMMENT 'Index value indicating how much higher the composition value is compared to the average composition value for all Fresh Segments clients’ customers for this interest in the same month (e.g., 6.19 means 6.19x the average)',
#   ranking INT COMMENT 'Ranking of the interest based on the index value in the given month year (e.g., 1 for the highest index value)',
#   percentile_ranking DOUBLE COMMENT 'Percentile ranking of the interest based on its index value, indicating its position relative to other interests in the same month year (e.g., 99.86 means it is in the top 0.14%)'
# )
# COMMENT "The interest metrics table represents the performance of specific interests based on the client's customer base"
# STORED AS PARQUET
# LOCATION 's3://sql-case-studies/fresh_segments/interest_metrics/'
# TBLPROPERTIES ('classification'='parquet', 'parquet.compress'='SNAPPY');
#
# --------------------------------------------------

# %%
for ddl in ddls.values():
    response = athena.create_table(database=database, query=ddl, wait=wait)
    response
# Out:
# Query executed successfully
# Query executed successfully

# %%
for table in tables:
    athena.query(
        database=database,
        query=f""" 
                SELECT
                    *
                FROM
                    {database}.{table} 
                LIMIT 10;
              """,
        ctas_approach=ctas_approach,
    )
# Out:
#    id              interest_name  \
# 0   1        Fitness Enthusiasts
# 1   2                     Gamers
# 2   3            Car Enthusiasts
# 3   4  Luxury Retail Researchers
# 4   5  Brides & Wedding Planners
# 5   6          Vacation Planners
# 6   7     Motorcycle Enthusiasts
# 7   8      Business News Readers
# 8  12      Thrift Store Shoppers
# 9  13  Advertising Professionals
#
#                                     interest_summary          created_at  \
# 0  Consumers using fitness tracking apps and webs... 2016-05-26 14:57:59
# 1  Consumers researching game reviews and cheat c... 2016-05-26 14:57:59
# 2        Readers of automotive news and car reviews. 2016-05-26 14:57:59
# 3  Consumers researching luxury product reviews a... 2016-05-26 14:57:59
# 4      People researching wedding ideas and vendors. 2016-05-26 14:57:59
# 5  Consumers reading reviews of vacation destinat... 2016-05-26 14:57:59
# 6            Readers of motorcycle news and reviews. 2016-05-26 14:57:59
# 7           Readers of online business news content. 2016-05-26 14:57:59
# 8  Consumers shopping online for clothing at thri... 2016-05-26 14:57:59
# 9         People who read advertising industry news. 2016-05-26 14:57:59
#
#         last_modified
# 0 2018-05-23 11:30:12
# 1 2018-05-23 11:30:12
# 2 2018-05-23 11:30:12
# 3 2018-05-23 11:30:12
# 4 2018-05-23 11:30:12
# 5 2018-05-23 11:30:13
# 6 2018-05-23 11:30:13
# 7 2018-05-23 11:30:12
# 8 2018-03-16 13:14:00
# 9 2018-05-23 11:30:12
#    record_month  record_year month_year  interest_id  composition  \
# 0             7         2018    07-2018        32486        11.89
# 1             7         2018    07-2018         6106         9.93
# 2             7         2018    07-2018        18923        10.85
# 3             7         2018    07-2018         6344        10.32
# 4             7         2018    07-2018          100        10.77
# 5             7         2018    07-2018           69        10.82
# 6             7         2018    07-2018           79        11.21
# 7             7         2018    07-2018         6111        10.71
# 8             7         2018    07-2018         6214         9.71
# 9             7         2018    07-2018        19422        10.11
#
#    index_value  ranking  percentile_ranking
# 0         6.19        1               99.86
# 1         5.31        2               99.73
# 2         5.29        3               99.59
# 3         5.10        4               99.45
# 4         5.04        5               99.31
# 5         5.03        6               99.18
# 6         4.97        7               99.04
# 7         4.83        8               98.90
# 8         4.83        8               98.90
# 9         4.81       10               98.63

# %% [markdown]
# ## Drop Database & Table

# %%
for table in tables:
    athena.drop_table(database=database, table=table, wait=wait)
# Out:
# Query executed successfully
# Query executed successfully

# %%
athena.drop_database(database=database, wait=wait)
# Out:
# Query executed successfully
